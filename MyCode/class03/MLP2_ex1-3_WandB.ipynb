# %% [markdown]
# - For data processing and model creation, this example is almost the same as MLP2_ex1-1. However, there are many new codes regarding usages of the popular WandB (https://wandb.ai/), especially in the training part, .
#
# - In this example you will learn the following new topics:
#   - How to use the `dotenv` library to securely save your WandB API key in a separated file.
#   - How to use WandB (required a WandB account) to log several hyperparameters, save best models and their train/val/test results, and do hyperparameter tuning.

# %% [markdown]
# # 1. Preparation

# %% [markdown]
# ## 1.1 Non-WandB preparation

# %%
# List all NVIDIA GPUs as available in this computer (or Colab's session)
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import sys
print( f"Python {sys.version}\n" )

import os
import random
import time
import sklearn as sk
print( f"Scikit-Learn {sk.__version__}" )
import pandas as pd
print( f"Pandas {pd.__version__}\n" )

import numpy as np
print( f"NumPy {np.__version__}\n" )

import matplotlib.pyplot as plt
# %matplotlib inline

import torchinfo
print( f"torchinfo {torchinfo.__version__}" )
import torch
print( f"PyTorch {torch.__version__}" )

# Get all available accelerators such as CUDA, MPS, MTIA, or XPU
num_accelerators = torch.accelerator.device_count()

if (num_accelerators <= 0):
    print("|- No hardware accelerators found. Using CPU only.")
else:
    print(f"|- PyTorch detected {num_accelerators} hardware accelerator(s)")
    print(f"|- PyTorch detected '{torch.accelerator.current_accelerator().type.upper()}' as the current accelerator")

    # Check cuda availability
    if torch.cuda.is_available():
        num_gpus = torch.cuda.device_count()
        print(f"|- PyTorch detected {num_gpus} CUDA GPU(s):")

        # Important: The CUDA version in "nvidia-smi" must be equal or higher than "torch.version.cuda".
        # If they mismatch, it may cause silent hangs during heavy CUDA operations.
        # In that case, reinstall PyTorch from pytorch.org with the correct CUDA version.
        print(f"   |- {torch.version.cuda = }")
    for i in range(num_gpus):
        print(f"   |- CUDA GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
#
# Scikit-Learn 1.6.1
# Pandas 2.2.2
#
# NumPy 2.0.2
#
# torchinfo 1.8.0
# PyTorch 2.11.0+cpu
# |- No hardware accelerators found. Using CPU only.

# %% [markdown]
# ## 1.2 WandB preparation

# %%
# !pip install wandb

# Install dotenv to help manage API keys stored in ".env" file
# !pip install python-dotenv
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.28.0)
# Requirement already satisfied: click>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.4.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.51)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from wandb) (26.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.10.0)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.6)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.13.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2026.6.17)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.2)

# %%
import wandb
print(f'WandB {wandb.__version__}')
# Out:
# WandB 0.28.0

# %% [markdown]
# Login to WandB:
# - Prepare your personal WandB's API key (signing up required) and login by `wandb.login(key=YOUR_API_KEY_HERE)`
#   - Retrieve your WandB API key from https://wandb.ai/authorize
#   - Protect your API key by creating a text file named ".env" to store your API key like `WANDB_API_KEY = fdjkere12df4erdfdelre`. Then, use the `dotenv` library to load content in the ".env" file and get the API key.
# - If you've already logged in to WandB in a web browser, most of the times, Google Colab will recognize your WandB account and automatically log you in without having to enter your WandB's API key manually.

# %%
print("Make sure that you have an environment variable named 'WANDB_API_KEY' stored in .env file")

while True:
  choice = input('Ready to proceed (y/n) ? ').lower().strip()

  if choice == 'y':
    # Load 'WANDB_API_KEY' from the ".env" file
    from dotenv import load_dotenv
    load_dotenv()
    WANDB_API_KEY = os.getenv('WANDB_API_KEY')

    # Login with your WandB account
    wandb.login(key=WANDB_API_KEY)
    break

  elif choice == 'n':
    continue

  else:
    print('Invalid input. Try again.\n')
# Out:
# Make sure that you have an environment variable named 'WANDB_API_KEY' stored in .env file
# Ready to proceed (y/n) ? y
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: thitirat (gsas_nida) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
# WandB Connection Check: Verify that you are successfully logged in to WandB.
wandb_api = wandb.Api()

try:
    # api.viewer fetches the current authenticated user's details.
    # If this fails, it implies the API key is missing or invalid.
    user_info = wandb_api.viewer
    print(f"WandB Authentication Verified. Connected as: {user_info.entity}")

    WANDB_PROJECT_NAME = "DLclass_MLP2_PyTorch"
    WANDB_ENTITY = user_info.entity
    print(f"\nGlobal variable:\n- {WANDB_PROJECT_NAME = }\n- {WANDB_ENTITY = }")
except Exception as e:
    print("\n[Error] WandB Authentication Failed.")
    raise ConnectionError("Could not connect to WandB API. Please check your API key.") from e
# Out:
# WandB Authentication Verified. Connected as: gsas_nida
#
# Global variable:
# - WANDB_PROJECT_NAME = 'DLclass_MLP2_PyTorch'
# - WANDB_ENTITY = 'gsas_nida'

# %% [markdown]
# ## 1.3 Prepare global variables/functions

# %%
# Reproducibility & Device Configuration
def set_seeds(seed=42):
    """Sets fixed seeds for reproducibility across all libraries."""
    random.seed(seed)     # Controls Python's built-in random numbers.
    np.random.seed(seed)  # Controls NumPy's random arrays.
    torch.manual_seed(seed)           # Controls CPU weight initialization.
    torch.cuda.manual_seed_all(seed)  # Controls GPU weight initialization.

    # Ensure deterministic behavior for some PyTorch operations
    torch.backends.cudnn.deterministic = True # Ensure the GPU doesn't use "fast but slightly random" algorithms for math
    torch.backends.cudnn.benchmark = False
    print(f"Seeds set to {seed} for reproducibility.")

# %%
# Detect GPU (CUDA), Apple Silicon (MPS), or fallback to CPU
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# # 2. Prepare the dataset
#
# Load the dataset:

# %%
# Get the dataset from Keras (ready-to-use format)
from keras.datasets import boston_housing
(x_train, y_train), (x_valtest, y_valtest) = boston_housing.load_data()

# Split the validation set
# Complete the data splitting BEFORE normalization to prevent data leakage
x_val, x_test, y_val, y_test = sk.model_selection.train_test_split(x_valtest, y_valtest, test_size=0.5, random_state=42)

print(f"{x_train.shape=}, {y_train.shape=}")
print(f"{x_val.shape=}, {y_val.shape=}")
print(f"{x_test.shape=}, {y_test.shape=}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# x_train.shape=(404, 13), y_train.shape=(404,)
# x_val.shape=(51, 13), y_val.shape=(51,)
# x_test.shape=(51, 13), y_test.shape=(51,)

# %% [markdown]
# Preview the dataset:

# %%
def boston_dataframe(x, y):
    df = pd.DataFrame(x, columns=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT' ] )
    df['MEDV'] = pd.Series(y)
    return df

print('===== PREVIEW: THE TRAIN SET =====')
display( boston_dataframe(x_train,y_train).describe().style.format(precision=2) )
print('\n===== PREVIEW: THE VAL SET =====')
display( boston_dataframe(x_val,y_val).describe().style.format(precision=2) )
print('\n===== PREVIEW: THE TEST SET =====')
display( boston_dataframe(x_test,y_test).describe().style.format(precision=2) )
# Out:
# ===== PREVIEW: THE TRAIN SET =====
# <style type="text/css">
# </style>
# <table id="T_9730b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9730b_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_9730b_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_9730b_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_9730b_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_9730b_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_9730b_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_9730b_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_9730b_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_9730b_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_9730b_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_9730b_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_9730b_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_9730b_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_9730b_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9730b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T
class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_798d5_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_798d5_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_798d5_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_798d5_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_798d5_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_798d5_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_798d5_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_798d5_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_798d5_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_798d5_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_798d5_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_798d5_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_798d5_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_798d5_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_798d5_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_798d5_row0_col0" class="data row0 col0" >51.00</td>
#       <td id="T_798d5_row0_col1" class="data row0 col1" >51.00</td>
#       <td id="T_798d5_row0_col2" class="data row0 col2" >51.00</td>
#       <td id="T_798d5_row0_col3" class="data row0 col3" >51.00</td>
#       <td id="T_798d5_row0_col4" class="data row0 col4" >51.00</td>
#       <td id="T_798d5_row0_col5" class="data row0 col5" >51.00</td>
#       <td id="T_798d5_row0_col6" class="data row0 col6" >51.00</td>
#       <td id="T_798d5_row0_col7" class="data row0 col7" >51.00</td>
#       <td id="T_798d5_row0_col8" class="data row0 col8" >51.00</td>
#       <td id="T_798d5_row0_col9" class="data row0 col9" >51.00</td>
#       <td id="T_798d5_row0_col10" class="data row0 col10" >51.00</td>
#       <td id="T_798d5_row0_col11" class="data row0 col11" >51.00</td>
#       <td id="T_798d5_row0_col12" class="data row0 col12" >51.00</td>
#       <td id="T_798d5_row0_col13" class="data row0 col13" >51.00</td>
#     </tr>
#     <tr>
#       <th id="T_798d5_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_798d5_row1_col0" class="data row1 col0" >3.05</td>
#       <td id="T_798d5_row1_col1" class="data row1 col1" >12.55</td>
#       <td id="T_798d5_row1_col2" class="data row1 col2" >11.26</td>
#       <td id="T_798d5_row1_col3" class="data row1 col3" >0.12</td>
#       <td id="T_798d5_row1_col4" class="data row1 col4" >0.55</td>
#       <td id="T_798d5_row1_col5" class="data row1 col5" >6.44</td>
#       <td id="T_798d5_row1_col6" class="data row1 col6" >66.71</td>
#       <td id="T_798d5_row1_col7" class="data row1 col7" >3.89</td>
#       <td id="T_798d5_row1_col8" class="data row1 col8" >9.69</td>
#       <td id="T_798d5_row1_col9" class="data row1 col9" >408.51</td>
#       <td id="T_798d5_row1_col10" class="data row1 col10" >17.85</td>
#       <td id="T_798d5_row1_col11" class="data row1 col11" >373.23</td>
#       <td id="T_798d5_row1_col12" class="data row1 col12" >11.49</td>
#       <td id="T_798d5_row1_col13" class="data row1 col13" >24.68</td>
#     </tr>
#     <tr>
#       <th id="T_798d5_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_798d5_row2_col0" class="data row2 col0" >5.43</td>
#       <td id="T_798d5_row2_col1" class="data row2 col1" >20.84</td>
#       <td id="T_798d5_row2_col2" class="data row2 col2" >7.20</td>
#       <td id="T_798d5_row2_col3" class="data row2 col3" >0.33</td>
#       <td id="T_798d5_row2_col4" class="data row2 col4" >0.12</td>
#       <td id="T_798d5_row2_col5" class="data row2 col5" >0.72</td>
#       <td id="T_798d5_row2_col6" class="data row2 col6" >28.61</td>
#       <td id="T_798d5_row2_col7" class="data row2 col7" >2.29</td>
#       <td id="T_798d5_row2_col8" class="data row2 col8" >8.58</td>
#       <td id="T_798d5_row2_col9" class="data row2 col9" >172.58</td>
#       <td id="T_798d5_row2_col10" class="data row2 col10" >2.28</td>
#       <td id="T_798d5_row2_col11" class="data row2 col11" >58.64</td>
#       <td id="T_798d5_row2_col12" class="data row2 col12" >6.07</td>
#       <td id="T_798d5_row2_col13" class="data row2 col13" >10.32</td>
#     </tr>
#     <tr>
#       <th id="T_798d5_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_798d5_row3_col0" class="data row3 col0" >0.01</td>
#       <td id="T_798d5_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_798d5_row3_col2" class="data row3 col2" >1.22</td>
#       <td id="T_798d5_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_798d5_row3_col4" class="data row3 col4" >0.39</td>
#       <td id="T_798d5_row3_col5" class="data row3 col5" >5.04</td>
#       <td id="T_798d5_row3_col6" class="data row3 col6" >6.80</td>
#       <td id="T_798d5_row3_col7" class="data row3 col7" >1.53</td>
#       <td id="T_798d5_row3_col8" class="data row3 col8" >1.00</td>
#       <td id="T_798d5_row3_col9" class="data row3 col9" >188.00</td>
#       <td id="T_798d5_row3_col10" class="data row3 col10" >13.00</td>
#       <td id="T_798d5_row3_col11" class="data row3 col11" >24.65</td>
#       <td id="T_798d5_row3_col12" class="data row3 col12" >1.92</td>
#       <td id="T_798d5_row3_col13" class="data row3 col13" >5.60</td>
#     </tr>
#     <tr>
#       <th id="T_798d5_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_798d5_row4_col0" class="data row4 col0" >0.08</td>
#       <td id="T_798d5_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_798d5_row4_col2" class="data row4 col2" >5.06</td>
#       <td id="T_798d5_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_798d5_row4_col4" class="data row4 col4" >0.45</td>
#       <td id="T_798d5_row4_col5" class="data row4 col5" >5.96</td>
#       <td id="T_798d5_row4_col6" class="data row4 col6" >43.90</td>
#       <td id="T_798d5_row4_col7" class="data row4 col7" >2.09</td>
#       <td id="T_798d5_row4_col8" class="data row4 col8" >4.50</td>
#       <td id="T_798d5_row4_col9" class="data row4 col9" >274.50</td>
#       <td id="T_798d5_row4_col10" class="data row4 col10" >16.25</td>
#       <td id="T_798d5_row4_col11" class="data row4 col11" >378.22</td>
#       <td id="T_798d5_row4_col12" class="data row4 col12" >7.13</td>
#       <td id="T_798d5_row4_col13" class="data row4 col13" >19.40</td>
#     </tr>
#     <tr>
#       <th id="T_798d5_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_798d5_row5_col0" class="data row5 col0" >0.21</td>
#       <td id="T_798d5_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_798d5_row5_col2" class="data row5 col2" >9.69</td>
#       <td id="T_798d5_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_798d5_row5_col4" class="data row5 col4" >0.55</td>
#       <td id="T_798d5_row5_col5" class="data row5 col5" >6.34</td>
#       <td id="T_798d5_row5_col6" class="data row5 col6" >70.20</td>
#       <td id="T_798d5_row5_col7" class="data row5 col7" >2.89</td>
#       <td id="T_798d5_row5_col8" class="data row5 col8" >5.00</td>
#       <td id="T_798d5_row5_col9" class="data row5 col9" >330.00</td>
#       <td id="T_798d5_row5_col10" class="data row5 col10" >18.00</td>
#       <td id="T_798d5_row5_col11" class="data row5 col11" >391.98</td>
#       <td id="T_798d5_row5_col12" class="data row5 col12" >10.29</td>
#       <td id="T_798d5_row5_col13" class="data row5 col13" >21.70</td>
#     </tr>
#     <tr>
#       <th id="T_798d5_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_798d5_row6_col0" class="data row6 col0" >3.29</td>
#       <td id="T_798d5_row6_col1" class="data row6 col1" >21.00</td>
#       <td id="T_798d5_row6_col2" class="data row6 col2" >18.10</td>
#       <td id="T_798d5_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_798d5_row6_col4" class="data row6 col4" >0.61</td>
#       <td id="
# ===== PREVIEW: THE TEST SET =====
# <style type="text/css">
# </style>
# <table id="T_64134" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64134_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_64134_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_64134_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_64134_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_64134_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_64134_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_64134_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_64134_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_64134_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_64134_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_64134_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_64134_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_64134_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_64134_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64134_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_64134_row0_col0" class="data row0 col0" >51.00</td>
#       <td id="T_64134_row0_col1" class="data row0 col1" >51.00</td>
#       <td id="T_64134_row0_col2" class="data row0 col2" >51.00</td>
#       <td id="T_64134_row0_col3" class="data row0 col3" >51.00</td>
#       <td id="T_64134_row0_col4" class="data row0 col4" >51.00</td>
#       <td id="T_64134_row0_col5" class="data row0 col5" >51.00</td>
#       <td id="T_64134_row0_col6" class="data row0 col6" >51.00</td>
level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_64134_row4_col0" class="data row4 col0" >0.09</td>
#       <td id="T_64134_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_64134_row4_col2" class="data row4 col2" >5.91</td>
#       <td id="T_64134_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_64134_row4_col4" class="data row4 col4" >0.45</td>
#       <td id="T_64134_row4_col5" class="data row4 col5" >6.05</td>
#       <td id="T_64134_row4_col6" class="data row4 col6" >39.90</td>
#       <td id="T_64134_row4_col7" class="data row4 col7" >2.33</td>
#       <td id="T_64134_row4_col8" class="data row4 col8" >4.00</td>
#       <td id="T_64134_row4_col9" class="data row4 col9" >290.00</td>
#       <td id="T_64134_row4_col10" class="data row4 col10" >17.85</td>
#       <td id="T_64134_row4_col11" class="data row4 col11" >377.53</td>
#       <td id="T_64134_row4_col12" class="data row4 col12" >7.53</td>
#       <td id="T_64134_row4_col13" class="data row4 col13" >17.20</td>
#     </tr>
#     <tr>
#       <th id="T_64134_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_64134_row5_col0" class="data row5 col0" >0.25</td>
#       <td id="T_64134_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_64134_row5_col2" class="data row5 col2" >9.90</td>
#       <td id="T_64134_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_64134_row5_col4" class="data row5 col4" >0.52</td>
#       <td id="T_64134_row5_col5" class="data row5 col5" >6.18</td>
#       <td id="T_64134_row5_col6" class="data row5 col6" >75.00</td>
#       <td id="T_64134_row5_col7" class="data row5 col7" >3.38</td>
#       <td id="T_64134_row5_col8" class="data row5 col8" >5.00</td>
#       <td id="T_64134_row5_col9" class="data row5 col9" >330.00</td>
#       <td id="T_64134_row5_col10" class="data row5 col10" >19.20</td>
#       <td id="T_64134_row5_col11" class="data row5 col11" >392.30</td>
#       <td id="T_64134_row5_col12" class="data row5 col12" >11.41</td>
#       <td id="T_64134_row5_col13" class="data row5 col13" >22.20</td>
#     </tr>
#     <tr>
#       <th id="T_64134_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_64134_row6_col0" class="data row6 col0" >3.80</td>
#       <td id="T_64134_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_64134_row6_col2" class="data row6 col2" >18.10</td>
#       <td id="T_64134_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_64134_row6_col4" class="data row6 col4" >0.59</td>
#       <td id="T_

# %% [markdown]
# Normalize each feature (in X) separately:

# %%
# Compute means and SDs from *the train set*
# 'axis' = Axis or axes along which the means are computed. The default is to compute the mean of the flattened array.
mean = x_train.mean(axis=0)
sd = x_train.std(axis=0)
print(f"{mean.shape=} , {sd.shape=}\n")

# Normalize 13 features
x_train_norm = ( x_train - mean ) / sd
x_val_norm = ( x_val - mean ) / sd
x_test_norm = ( x_test - mean ) / sd

# Inspect
print('===== PREVIEW: THE TRAIN SET (AFTER NORM) =====')
display( boston_dataframe(x_train_norm,y_train).describe().style.format(precision=2) )
print('\n===== PREVIEW: THE VAL SET (AFTER NORM) =====')
display( boston_dataframe(x_val_norm,y_val).describe().style.format(precision=2) )
print('\n===== PREVIEW: THE TEST SET (AFTER NORM) =====')
display( boston_dataframe(x_test_norm,y_test).describe().style.format(precision=2) )
# Out:
# mean.shape=(13,) , sd.shape=(13,)
#
# ===== PREVIEW: THE TRAIN SET (AFTER NORM) =====
# <style type="text/css">
# </style>
# <table id="T_a90ef" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a90ef_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_a90ef_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_a90ef_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_a90ef_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_a90ef_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_a90ef_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_a90ef_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_a90ef_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_a90ef_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_a90ef_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_a90ef_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_a90ef_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_a90ef_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_a90ef_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a90ef_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_a90ef_row0_col0" class="data row0 col0" >404.00</td>
#       <td id="T_a90ef_row0_col1" class="data row0 col1" >404.00</td>
#       <td id="T_a90ef_row0_col2" class="data row0 col2" >404.00</td>
#       <td id="T_a90ef_row0_col3" class="data row0 col3" >404.00</td>
#       <td id="T_a90ef_row0_col4" class="data row0 col4" >404.00</td>
#       <td id="T_a90ef_row0_col5" class="data row0 col5" >404.00</td>
#       <td id="T_a90ef_row0_col6" class="data row0 col6" >404.00</td>
#       <td id="T_a90ef_row0_col7" class="data row0 col7" >404.00</td>
#       <td id="T_a90ef_row0_col8" class="data row0 col8" >404.00</td>
#       <td id="T_a90ef_row0_col9" class="data row0 col9" >404.00</td>
#       <td id="T_a90ef_row0_col10" class="data row0 col10" >404.00</td>
#       <td id="T_a90ef_row0_col11" class="data row0 col11" >404.00</td>
#       <td id="T_a90ef_row0_col12" class="data row0 col12" >404.00</td>
#       <td id="T_a90ef_row0_col13" class="data row0 col13" >404.00</td>
#     </tr>
#     <tr>
#       <th id="T_a90ef_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T
level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_a90ef_row4_col0" class="data row4 col0" >-0.40</td>
#       <td id="T_a90ef_row4_col1" class="data row4 col1" >-0.48</td>
#       <td id="T_a90ef_row4_col2" class="data row4 col2" >-0.88</td>
#       <td id="T_a90ef_row4_col3" class="data row4 col3" >-0.26</td>
#       <td id="T_a90ef_row4_col4" class="data row4 col4" >-0.89</td>
#       <td id="T_a90ef_row4_col5" class="data row4 col5" >-0.55</td>
#       <td id="T_a90ef_row4_col6" class="data row4 col6" >-0.84</td>
#       <td id="T_a90ef_row4_col7" class="data row4 col7" >-0.82</td>
#       <td id="T_a90ef_row4_col8" class="data row4 col8" >-0.63</td>
#       <td id="T_a90ef_row4_col9" class="data row4 col9" >-0.76</td>
#       <td id="T_a90ef_row4_col10" class="data row4 col10" >-0.57</td>
#       <td id="T_a90ef_row4_col11" class="data row4 col11" >0.21</td>
#       <td id="T_a90ef_row4_col12" class="data row4 col12" >-0.81</td>
#       <td id="T_a90ef_row4_col13" class="data row4 col13" >16.68</td>
#     </tr>
#     <tr>
#       <th id="T_a90ef_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_a90ef_row5_col0" class="data row5 col0" >-0.38</td>
#       <td id="T_a90ef_row5_col1" class="data row5 col1" >-0.48</td>
#       <td id="T_a90ef_row5_col2" class="data row5 col2" >-0.21</td>
#       <td id="T_a90ef_row5_col3" class="data row5 col3" >-0.26</td>
#       <td id="T_a90ef_row5_col4" class="data row5 col4" >-0.17</td>
#       <td id="T_a90ef_row5_col5" class="data row5 col5" >-0.10</td>
#       <td id="T_a90ef_row5_col6" class="data row5 col6" >0.34</td>
#       <td id="T_a90ef_row5_col7" class="data row5 col7" >-0.29</td>
#       <td id="T_a90ef_row5_col8" class="data row5 col8" >-0.51</td>
#       <td id="T_a90ef_row5_col9" class="data row5 col9" >-0.46</td>
#       <td id="T_a90ef_row5_col10" class="data row5 col10" >0.28</td>
#       <td id="T_a90ef_row5_col11" class="data row5 col11" >0.39</td>
#       <td id="T_a90ef_row5_col12" class="data row5 col12" >-0.19</td>
#       <td id="T_a90ef_row5_col13" class="data row5 col13" >20.75</td>
#     </tr>
#     <tr>
#       <th id="T_a90ef_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_a90ef_row6_col0" class="data row6 col0" >-0.01</td>
#       <td id="T_a90ef_row6_col1" class="data row6 col1" >0.04</td>
#       <td id="T_a90ef_row6_col2" class="data row6 col2" >1.03</td>
#       <td id="T_a90ef_row6_col3" class="data row6 col3" >-0.26</td>
#       <td id="T_a90ef_row6_col4" class="data row6 col4" >0.
# ===== PREVIEW: THE VAL SET (AFTER NORM) =====
# <style type="text/css">
# </style>
# <table id="T_aa8f3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa8f3_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_aa8f3_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_aa8f3_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_aa8f3_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_aa8f3_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_aa8f3_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_aa8f3_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_aa8f3_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_aa8f3_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_aa8f3_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_aa8f3_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_aa8f3_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_aa8f3_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_aa8f3_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa8f3_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_aa8f3_row0_col0" class="data row0 col0" >51.00</td>
#       <td id="T_aa8f3_row0_col1" class="data row0 col1" >51.00</td>
#       <td id="T_aa8f3_row0_col2" class="data row0 col2" >51.00</td>
#       <td id="T_aa8f3_row0_col3" class="data row0 col3" >51.00</td>
#       <td id="T_aa8f3_row0_col4" class="data row0 col4" >51.00</td>
#       <td id="T_aa8f3_row0_col5" class="data row0 col5" >51.00</td>
#       <td id="T_aa8f3_row0_col6" class="data row0 col6" >51.00</td>
#       <td id="T_aa8f3_row0_col7" class="data row0 col7" >51.00</td>
#       <td id="T_aa8f3_row0_col8" class="data row0 col8" >51.00</td>
#       <td id="T_aa8f3_row0_col9" class="data row0 col9" >51.00</td>
#       <td id="T_aa8f3_row0_col10" class="data row0 col10" >51.00</td>
#       <td id="T_aa8f3_row0_col11" class="data row0 col11" >51.00</td>
#       <td id="T_aa8f3_row0_col12" class="data row0 col12" >51.00</td>
#       <td id="T_aa8f3_row0_col13" class="data row0 col13" >51.00</td>
#     </tr>
#     <tr>
#       <th id="T_aa8f3_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_aa8f3_row1_col0" class="data row1 col0" >-0.08</td>
#       <td id="T_aa8f3_row1_col1" class="data row1 col1" >0.05</td>
#       <td id="T_aa8f3_row1_col2" class="data row1 col2" >0.02</td>
#       <td id="T_aa8f3_row1_col3" class="data row1 col3" >0.23</td>
#       <td id="T_aa8f3_row1_col4" class="data row1 col4" >-0.03</td>
#       <td id="T_aa8f3_row1_col5" class="data row1 col5" >0.24</td>
#       <td id="T_aa8f3_row1_col6" class="data row1 col6" >-0.08</td>
#       <td id="T_aa8f3_row1_col7" class="data row1 col7" >0.07</td>
#       <td id="T_aa8f3_row1_col8" class="data row1 col8" >0.03</td>
#       <td id="T_aa8f3_row1_col9" class="data row1 col9" >0.02</td>
#       <td id="T_aa8f3_row1_col10" class="data row1 col10" >-0.29</td>
#       <td id="T_aa8f3_row1_col11" class="data row1 col11" >0.20</td>
#       <td id="T_aa8f3_row1_col12" class="data row1 col12" >-0.17</td>
#       <td id="T_aa8f3_row1_col13" class="data row1 col13" >24.68</td>
#     </tr>
#     <tr>
#       <th id="T_aa8f3_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_aa8f3_row2_col0" class="data row2 col0" >0.59</td>
#       <td id="T_aa8f3_row2_col1" class="data row2 col1" >0.88</td>
#       <td id="T_aa8f3_row2_col2" class="data row2 col2" >1.06</td>
#       <td id="T_aa8f3_row2_col3" class="data row2 col3" >1.35</td>
#       <td id="T_aa8f3_row2_col4" class="data row2 col4" >1.01</td>
#       <td id="T_aa8f3_row2_col5" class="data row2 col5" >1.01</td>
#       <td id="T_aa8f3_row2_col6" class="data row2 col6" >1.03</td>
level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_aa8f3_row5_col0" class="data row5 col0" >-0.38</td>
#       <td id="T_aa8f3_row5_col1" class="data row5 col1" >-0.48</td>
#       <td id="T_aa8f3_row5_col2" class="data row5 col2" >-0.21</td>
#       <td id="T_aa8f3_row5_col3" class="data row5 col3" >-0.26</td>
#       <td id="T_aa8f3_row5_col4" class="data row5 col4" >-0.09</td>
#       <td id="T_aa8f3_row5_col5" class="data row5 col5" >0.11</td>
#       <td id="T_aa8f3_row5_col6" class="data row5 col6" >0.04</td>
#       <td id="T_aa8f3_row5_col7" class="data row5 col7" >-0.42</td>
#       <td id="T_aa8f3_row5_col8" class="data row5 col8" >-0.51</td>
#       <td id="T_aa8f3_row5_col9" class="data row5 col9" >-0.46</td>
#       <td id="T_aa8f3_row5_col10" class="data row5 col10" >-0.22</td>
#       <td id="T_aa8f3_row5_col11" class="data row5 col11" >0.40</td>
#       <td id="T_aa8f3_row5_col12" class="data row5 col12" >-0.34</td>
#       <td id="T_aa8f3_row5_col13" class="data row5 col13" >21.70</td>
#     </tr>
#     <tr>
#       <th id="T_aa8f3_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_aa8f3_row6_col0" class="data row6 col0" >-0.05</td>
#       <td id="T_aa8f3_row6_col1" class="data row6 col1" >0.40</td>
#       <td id="T_aa8f3_row6_col2" class="data row6 col2" >1.03</td>
#       <td id="T_aa8f3_row6_col3" class="data row6 col3" >-0.26</td>
#       <td id="T_aa8f3_row6_col4" class="data row6 col4" >0.48</td>
# ===== PREVIEW: THE TEST SET (AFTER NORM) =====
# <style type="text/css">
# </style>
# <table id="T_d50a6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d50a6_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_d50a6_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_d50a6_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_d50a6_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_d50a6_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_d50a6_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_d50a6_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_d50a6_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_d50a6_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_d50a6_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_d50a6_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_d50a6_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_d50a6_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_d50a6_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d50a6_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_d50a6_row0_col0" class="data row0 col0" >51.00</td>
#       <td id="T_d50a6_row0_col1" class="data row0 col1" >51.00</td>
#       <td id="T_d50a6_row0_col2" class="data row0 col2" >51.00</td>
#       <td id="T_d50a6_row0_col3" class="data row0 col3" >51.00</td>
#       <td id="T_d50a6_row0_col4" class="data row0 col4" >51.00</td>
#       <td id="T_d50a6_row0_col5" class="data row0 col5" >51.00</td>
#       <td id="T_d50a6_row0_col6" class="data row0 col6" >51.00</td>
#       <td id="T_d50a6_row0_col7" class="data row0 col7" >51.00</td>
#       <td id="T_d50a6_row0_col8" class="data row0 col8" >51.00</td>
#       <td id="T_d50a6_row0_col9" class="data row0 col9" >51.00</td>
#       <td id="T_d50a6_row0_col10" class="data row0 col10" >51.00</td>
#       <td id="T_d50a6_row0_col11" class="data row0 col11" >51.00</td>
#       <td id="T_d50a6_row0_col12" class="data row0 col12" >51.00</td>
#       <td id="T_d50a6_row0_col13" class="data row0 col13" >51.00</td>
#     </tr>
#     <tr>
#       <th id="T_d50a6_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T
#       <td id="T_d50a6_row3_col9" class="data row3 col9" >-1.32</td>
#       <td id="T_d50a6_row3_col10" class="data row3 col10" >-1.72</td>
#       <td id="T_d50a6_row3_col11" class="data row3 col11" >-3.48</td>
#       <td id="T_d50a6_row3_col12" class="data row3 col12" >-1.22</td>
#       <td id="T_d50a6_row3_col13" class="data row3 col13" >7.00</td>
#     </tr>
#     <tr>
#       <th id="T_d50a6_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_d50a6_row4_col0" class="data row4 col0" >-0.40</td>
#       <td id="T_d50a6_row4_col1" class="data row4 col1" >-0.48</td>
#       <td id="T_d50a6_row4_col2" class="data row4 col2" >-0.76</td>
#       <td id="T_d50a6_row4_col3" class="data row4 col3" >-0.26</td>
#       <td id="T_d50a6_row4_col4" class="data row4 col4" >-0.96</td>
#       <td id="T_d50a6_row4_col5" class="data row4 col5" >-0.30</td>
#       <td id="T_d50a6_row4_col6" class="data row4 col6" >-1.04</td>
#       <td id="T_d50a6_row4_col7" class="data row4 col7" >-0.69</td>
#       <td id="T_d50a6_row4_col8" class="data row4 col8" >-0.63</td>
#       <td id="T_d50a6_row4_col9" class="data row4 col9" >-0.70</td>
#       <td id="T_d50a6_row4_col10" class="data row4 col10" >-0.28</td>
#       <td id="T_d50a6_row4_col11" class="data row4 col11" >0.24</td>
#       <td id="T_d50a6_row4_col12" class="data row4 col12" >-0.72</td>
#       <td id="T_d50a6_row4_col13" class="data row4 col13" >17.20</td>
#     </tr>
#     <tr>
#       <th id="T_d50a6_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_d50a6_row5_col0" class="data row5 col0" >-0.38</td>
#       <td id="T_d50a6_row5_col1" class="data row5 col1" >-0.48</td>
#       <td id="T_d50a6_row5_col2" class="data row5 col2" >-0.18</td>
#       <td id="T_d50a6_row5_col3" class="data row5 col3" >-0.26</td>
#       <td id="T_d50a6_row5_col4" class="data row5 col4" >-0.28</td>
#       <td id="T_d50a6_row5_col5" class="data row5 col5" >-0.12</td>
#       <td id="T_d50a6_row5_col6" class="data row5 col6" >0.21</td>
#       <td id="T_d50a6_row5_col7" class="data row5 col7" >-0.18</td>
#       <td id="T_d50a6_row5_col8" class="data row5 col8" >-0.51</td>
#       <td id="T_d50a6_row5_col9" class="data row5 col9" >-0.46</td>
#       <td id="T_d50a6_row5_col10" class="data row5 col10" >0.33</td>
#       <td id="T_d50a6_row5_col11" class="data row5 col11" >0.40</td>
#       <td id="T_d50a6_row5_col12" class="data row5 col12" >-0.18</td>
#       <td id="T_d50a6_row5_col13" class="data row5 col13" >22.20</td>
#     </tr>
#     <tr>
#       <th id="T_d50a6_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_d50a6_row6_col0" class="data row6 col0" >0.01</td>
#       <td id="T_d50a6_row6_col1" class="data row6 col1" >-0.48</td>
#       <td id="T_d50a6_row6_col2" class="data row6 col2" >1.03</td>
#       <td id="T_d50a6_row6_col3" class="data row6 col3" >-0.26</td>
#       <td id="T_d50a6_row6_col4" class="data row6 col4" >0.29</td>
#       <

# %% [markdown]
# Convert to PyTorch tensors, reshape, and create Tensor datasets:

# %%
X_train = torch.tensor(x_train_norm, dtype=torch.float32)
X_val = torch.tensor(x_val_norm, dtype=torch.float32)
X_test = torch.tensor(x_test_norm, dtype=torch.float32)
Y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
Y_val = torch.tensor(y_val, dtype=torch.float32).view(-1, 1)
Y_test = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)
print(f"{X_train.shape=}, {Y_train.shape=}")
print(f"{X_val.shape=}, {Y_val.shape=}")
print(f"{X_test.shape=}, {Y_test.shape=}")

train_ds = torch.utils.data.TensorDataset(X_train, Y_train)
val_ds = torch.utils.data.TensorDataset(X_val, Y_val)
test_ds = torch.utils.data.TensorDataset(X_test, Y_test)
# Out:
# X_train.shape=torch.Size([404, 13]), Y_train.shape=torch.Size([404, 1])
# X_val.shape=torch.Size([51, 13]), Y_val.shape=torch.Size([51, 1])
# X_test.shape=torch.Size([51, 13]), Y_test.shape=torch.Size([51, 1])

# %% [markdown]
# # 3. Create the network architecture

# %%
class BostonModel(torch.nn.Module):
    def __init__(self, input_dim=13):
        super().__init__()
        self.net = torch.nn.Sequential(
            torch.nn.Linear(input_dim, 64),
            torch.nn.BatchNorm1d(64),
            torch.nn.ReLU(),
            torch.nn.Dropout(0.2),

            torch.nn.Linear(64, 32),
            torch.nn.BatchNorm1d(32),
            torch.nn.ReLU(),
            torch.nn.Dropout(0.1),

            torch.nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.net(x)

# %%
model = BostonModel().to(device)
model
# Out:
# BostonModel(
#   (net): Sequential(
#     (0): Linear(in_features=13, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.1, inplace=False)
#     (8): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
torchinfo.summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# BostonModel                              --
# ├─Sequential: 1-1                        --
# │    └─Linear: 2-1                       896
# │    └─BatchNorm1d: 2-2                  128
# │    └─ReLU: 2-3                         --
# │    └─Dropout: 2-4                      --
# │    └─Linear: 2-5                       2,080
# │    └─BatchNorm1d: 2-6                  64
# │    └─ReLU: 2-7                         --
# │    └─Dropout: 2-8                      --
# │    └─Linear: 2-9                       33
# =================================================================
# Total params: 3,201
# Trainable params: 3,201
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # 4. Train the model (train + val sets)

# %% [markdown]
# ## 4.1 Non-WandB preparation
#
# Prepare two modes of model saving and loading:

# %%
print("--- Model Export Menu ---")
print("1. Save Weight-Only")
print("2. Save Full-Checkpoint")
choice = input("Select an option (1-2): ").strip()

if (choice == '1'):
    save_weights_only = True
    best_model_path = 'best_weights.pt'
else:
    save_weights_only = False
    best_model_path = 'best_checkpoint.tar'
# Out:
# --- Model Export Menu ---
# 1. Save Weight-Only
# 2. Save Full-Checkpoint
# Select an option (1-2): 2

# %%
def save_model(model, optimizer, epoch, save_weights_only=save_weights_only, save_path=best_model_path):
    """
    Locally save the given model to disk

    Args:
        model (torch.nn.Module): The PyTorch model to be saved.
        optimizer (torch.optim.Optimizer): The optimizer associated.
        epoch (int): The current epoch number (the first epoch is 1).
        save_weights_only (bool): If True, only the model's weights (.pt) will be saved.
            Otherwise, the full state dictionary (.tar) will be saved.
            Default is to use the global variable 'save_weights_only'.
        save_path (str): The local path to save the model file.
            Default is to use the global variable 'best_model_path'.
    """
    if save_weights_only:
        # Weights only: lightweight and portable
        torch.save(model.state_dict(), save_path)
        print(f"---- Epoch {epoch+1:03d}: Weights saved to '{save_path}'")
    else:
        # Full Checkpoint: includes all metadata to resume training
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict()
        }
        torch.save( checkpoint, save_path )
        print(f"---- Epoch {epoch+1:03d}: Full checkpoint saved to '{save_path}'")

# %%
def load_model(save_path=best_model_path, model_instance=BostonModel()):
    """
    Loads a model regardless of whether it's a weight-only file or full checkpoint to the local disk.

    Args:
        save_path (str): The local path to the saved model file.
            Default is to use the global variable 'best_model_path'.
        model_instance (torch.nn.Module): An initialized instance of your model architecture.
            Default is to use the global variable 'BostonModel()'.

    Returns:
        torch.nn.Module: The loaded model instance that is set to eval mode.
    """
    loaded_obj = torch.load(save_path)

    if isinstance(loaded_obj, dict) and 'model_state_dict' in loaded_obj:
        # It's a full checkpoint
        model_instance.load_state_dict(loaded_obj['model_state_dict'])
    else:
        # It's a weight-only state_dict
        model_instance.load_state_dict(loaded_obj)

    return model_instance.eval()

# %% [markdown]
# Other training preparation:

# %%
@torch.inference_mode()
def evaluate(model, loader, criterion_mse, criterion_mae):
    """
    Evaluates the model on a given dataset using MSE and MAE metrics.
    Use this function with validation and test sets.

    Args:
        model (torch.nn.Module): The PyTorch model to evaluate.
        loader (torch.utils.data.DataLoader): DataLoader containing the dataset to evaluate on.
        criterion_mse (torch.nn.Module): The Mean Squared Error loss function.
        criterion_mae (torch.nn.Module): The Mean Absolute Error loss function.

    Returns:
        tuple: A tuple containing two floats:
            - avg_mse: The average Mean Squared Error over the dataset.
            - avg_mae: The average Mean Absolute Error over the dataset.
    """
    model.eval()

    total_mse = 0
    total_mae = 0
    for X, Y in loader:
        X, Y = X.to(device), Y.to(device)
        preds = model(X)
        total_mse += criterion_mse(preds, Y).item() * X.size(0)
        total_mae += criterion_mae(preds, Y).item() * X.size(0)

    return total_mse / len(loader.dataset), total_mae / len(loader.dataset)

# %% [markdown]
# ## 4.2 WandB preparation

# %%
# Define WandB's Sweep Configuration for hyperparameter tuning
sweep_configuration = {
    'method':'random',      # 'grid', 'random', or 'bayes'
    'name':'boston_sweep',
    'metric': {
        'goal': 'minimize',

        # Set what indicator to use, when sweep.best_run() considers which run is the best
        #'name':'val_mse',     # Target 'val_mse' from the last epoch
        'name':'best_val_mse'  # Target the absolute best epoch, not the last one
    },
    'parameters': {
        # Sweep for many values
        'batch_size': {'values': [16, 32, 64]},
        'learning_rate': {'max': 0.01, 'min': 0.0001},
        'optimizer': {'values': ['adam', 'sgd']},

        # Sweep for fixed values
        'architecture': {'values': ['MLP']},
        'epochs': {'value': 50},
    }
}

# %%
# Helper to automatically find the best sweep run from WandB, and load that best model to local disk
def auto_load_from_sweep(sweep_id, project=WANDB_PROJECT_NAME, entity=WANDB_ENTITY,
                         model_filename=best_model_path, model_instance=BostonModel()):
    """
    Uses WandB API to find the best run in the sweep and download the model artifact.

    This function queries the specified WandB sweep, identifies the run with the
    best metric (as defined in the sweep configuration), downloads the 'best_model_filename'
    checkpoint from that run, and loads the state dictionary into the provided model instance.

    Args:
        sweep_id (str): The unique identifier for the sweep (e.g., '8mvj23s1').
            This is returned by `wandb.sweep()`.
        project (str): The name of the WandB project where the sweep was logged
            (e.g., 'DLclass_MLP2_PyTorch').
        entity (str): The username or team name where the project is hosted.
            Use this if accessing a shared project or a specific team's workspace.
         model_filename (str): The name of the file containing the best model checkpoint/weights.
            The name must match the saved state dictionary.
            Default is the global variable 'best_model_path'.
        model_instance (torch.nn.Module): An initialized instance of your model architecture.
            The structure must match the saved state dictionary.
            Default to the global 'BostonModel()'.

    Returns:
        torch.nn.Module: The model instance with the best weights loaded and set to eval mode.
    """
    api = wandb.Api()

    # Construct sweep path
    sweep_path = f"{entity}/{project}/{sweep_id}" if entity else f"{project}/{sweep_id}"
    print(f"Analyzing sweep: {sweep_path}")

    # Get the sweep object
    sweep = api.sweep(sweep_path)

    # best_run() uses the 'metric' defined in your sweep_configuration (val_mse)
    # and the 'goal' (minimize) to find the top performing run automatically.
    best_run = sweep.best_run()

    print(f"Best Run Found: {best_run.name} (ID: {best_run.id})")
    print(f"Best {sweep.config['metric']['name']}: {best_run.summary.get(sweep.config['metric']['name'])}")

    # Download the artifact
    print(f"Downloading '{model_filename}'...")
    best_run.file(model_filename).download(replace=True, root=".")

    # Load locally
    model_instance = load_model(model_filename)
    model_instance.eval()

    print("Model loaded successfully!")
    return model_instance

# %% [markdown]
# ## 4.3 WandB train loop with Sweep

# %%
def train_sweep(config=None):
    """
    To use WandB's Sweep for hyperparameter tuning, the train loop must be wrapped inside a function.

    Args:
        config (dict, optional): A dictionary containing hyperparameters.
    """

    # Use Context Manager for easier cleanup and error handling
    with wandb.init(config=config) as run:  # Initialize a new wandb run
        # Access all hyperparams through wandb.config
        config = wandb.config

        # Optional: Fix the seed for reproducibility across sweep runs
        # If you want a set of hyperparams that work well despite of random initiation, comment this line out.
        set_seeds(42)

        # Initialize Model
        model = BostonModel().to(device)

        # Optional: Log model architecture and gradients
        wandb.watch(model, log="all", log_freq=10)

        # Link config to real values (DataLoaders)
        train_loader = torch.utils.data.DataLoader(train_ds, batch_size=config.batch_size, shuffle=True)
        val_loader = torch.utils.data.DataLoader(val_ds, batch_size=config.batch_size)
        test_loader = torch.utils.data.DataLoader(test_ds, batch_size=config.batch_size)

        # Link config to real values (Optimizer)
        if config.optimizer == "adam":
            optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate, weight_decay=1e-4)
        elif config.optimizer == "sgd":
            optimizer = torch.optim.SGD(model.parameters(), lr=config.learning_rate, momentum=0.9)

        # Update config to record the exact loss and metric class names used
        criterion_mse = torch.nn.MSELoss()  # Loss
        criterion_mae = torch.nn.L1Loss()   # Eval
        wandb.config.update({
            "loss_function": criterion_mse.__class__.__name__,
            "metric_function": criterion_mae.__class__.__name__
        })

        # Set the initial 'best_val_loss' to infinity
        best_val_loss = float('inf')

        # Training Loop
        for epoch in range(config.epochs):
            epoch_start = time.time()
            model.train()
            train_loss_mse = 0
            train_loss_mae = 0

            for X, Y in train_loader:
                X, Y = X.to(device), Y.to(device)
                optimizer.zero_grad()

                preds = model(X)
                loss_mse = criterion_mse(preds, Y)
                loss_mae = criterion_mae(preds, Y)

                loss_mse.backward()
                optimizer.step()

                train_loss_mse += loss_mse.detach() * X.size(0)
                train_loss_mae += loss_mae.detach() * X.size(0)

            # Calculate average epoch metrics
            avg_train_mse = train_loss_mse.item() / len(train_loader.dataset)
            avg_train_mae = train_loss_mae.item() / len(train_loader.dataset)

            # Validation
            val_mse, val_mae = evaluate(model, val_loader, criterion_mse, criterion_mae)
            epoch_duration = time.time() - epoch_start

            # Save Best Model
            if val_mse < best_val_loss:
                best_val_loss = val_mse

                # Save locally first
                save_model(model, optimizer, epoch, save_weights_only, best_model_path)

                # Save to WandB (associates file with the current run)
                # policy="now" uploads immediately, "live" uploads as it changes
                wandb.save(best_model_path, policy="now")

            # Log a per-epoch metric to WandB
            wandb.log({
                "epoch": epoch + 1,
                "train_mse": avg_train_mse,
                "train_mae": avg_train_mae,
                "val_mse": val_mse,
                "val_mae": val_mae,
                "best_val_mse": best_val_loss,
                "lr": optimizer.param_groups[0]['lr'],
                "time_per_epoch": epoch_duration
            })

            # Print the summary of this epoch
            print(f"Epoch {epoch+1:03d} | Time: {epoch_duration:.4f}s | Train MSE: {avg_train_mse:.2f} | Train MAE: {avg_train_mae:.2f} | Val MSE: {val_mse:.2f} | Val MAE: {val_mae:.2f}")

        # Final Evaluation on Test Set (Logged as summary)
        test_mse, test_mae = evaluate(model, test_loader, criterion_mse, criterion_mae)
        wandb.log({"test_mse": test_mse, "test_mae": test_mae})
        print(f"Sweep Finished. Test MSE: {test_mse}")

# %%
# Create the sweep in wandb servers
sweep_id = wandb.sweep(sweep_configuration, project=WANDB_PROJECT_NAME)

# Run the sweep agent
# count=5 means it will try 5 different hyperparameter combinations
wandb.agent(sweep_id, function=train_sweep, count=5)
# Out:
# Create sweep with ID: pxt0f7qw
# Sweep URL: https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw
# wandb: Agent Starting Run: wqj0q5po with config:
# wandb: 	architecture: MLP
# wandb: 	batch_size: 32
# wandb: 	epochs: 50
# wandb: 	learning_rate: 0.004946008232756917
# wandb: 	optimizer: adam
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# Tracking run with wandb version 0.28.0
# Run data is saved locally in <code>/content/wandb/run-20260818_141436-wqj0q5po</code>
# Syncing run <strong><a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/wqj0q5po' target="_blank">lilac-sweep-1</a></strong> to <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw</a>
#  View project at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch</a>
#  View sweep at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw</a>
#  View run at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/wqj0q5po' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/wqj0q5po</a>
# Seeds set to 42 for reproducibility.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# ---- Epoch 001: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 001 | Time: 0.1921s | Train MSE: 554.14 | Train MAE: 21.89 | Val MSE: 627.46 | Val MAE: 23.37
# ---- Epoch 002: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 002 | Time: 0.0554s | Train MSE: 490.45 | Train MAE: 20.80 | Val MSE: 508.06 | Val MAE: 21.40
# ---- Epoch 003: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 003 | Time: 0.0434s | Train MSE: 427.61 | Train MAE: 19.55 | Val MSE: 409.04 | Val MAE: 19.39
# ---- Epoch 004: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 004 | Time: 0.0588s | Train MSE: 355.05 | Train MAE: 17.84 | Val MSE: 344.45 | Val MAE: 17.79
# ---- Epoch 005: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 005 | Time: 0.0562s | Train MSE: 280.28 | Train MAE: 15.79 | Val MSE: 258.07 | Val MAE: 15.33
# ---- Epoch 006: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 006 | Time: 0.0493s | Train MSE: 216.71 | Train MAE: 13.64 | Val MSE: 212.92 | Val MAE: 13.72
# ---- Epoch 007: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 007 | Time: 0.0502s | Train MSE: 152.68 | Train MAE: 11.17 | Val MSE: 161.34 | Val MAE: 11.72
# ---- Epoch 008: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 008 | Time: 0.0509s | Train MSE: 93.11 | Train MAE: 8.42 | Val MSE: 92.42 | Val MAE: 8.51
# ---- Epoch 009: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 009 | Time: 0.0508s | Train MSE: 60.45 | Train MAE: 6.27 | Val MSE: 59.69 | Val MAE: 6.50
# ---- Epoch 010: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 010 | Time: 0.0545s | Train MSE: 39.55 | Train MAE: 4.96 | Val MSE: 27.92 | Val MAE: 4.26
# ---- Epoch 011: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 011 | Time: 0.0437s | Train MSE: 29.37 | Train MAE: 4.09 | Val MSE: 23.19 | Val MAE: 3.80
�▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_mse</td><td>█▇▆▅▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_mae</td><td>█▇▇▆▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_mse</td><td>█▇▆▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_mse</td><td>8.72349</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>lr</td><td>0.00495</td></tr><tr><td>test_mae</td><td>2.63399</td></tr><tr><td>test_mse</td><td>15.77897</td></tr><tr><td>time_per_epoch</td><td>0.05955</td></tr><tr><td>train_mae</td><td>3.23776</td></tr><tr><td>train_mse</td><td>18.12622</td></tr><tr><td>val_mae</td><td>2.49942</td></tr><tr><td>val_mse</td><td>11.22387</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lilac-sweep-1</strong> at: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/wqj0q5po' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/wqj0q5po</a><br> View project at: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20260818_141436-wqj0q5po/logs</code>
# wandb: Agent Starting Run: qyaefqcc with config:
# wandb: 	architecture: MLP
# wandb: 	batch_size: 32
# wandb: 	epochs: 50
# wandb: 	learning_rate: 0.004933157562588237
# wandb: 	optimizer: sgd
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# Tracking run with wandb version 0.28.0
# Run data is saved locally in <code>/content/wandb/run-20260818_141451-qyaefqcc</code>
# Syncing run <strong><a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/qyaefqcc' target="_blank">glowing-sweep-2</a></strong> to <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw</a>
#  View project at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch</a>
#  View sweep at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw</a>
#  View run at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/qyaefqcc' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/qyaefqcc</a>
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Seeds set to 42 for reproducibility.
# ---- Epoch 001: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 001 | Time: 0.0369s | Train MSE: 225.99 | Train MAE: 11.94 | Val MSE: 245.57 | Val MAE: 12.82
# ---- Epoch 002: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 002 | Time: 0.0420s | Train MSE: 56.09 | Train MAE: 5.45 | Val MSE: 56.69 | Val MAE: 5.95
# ---- Epoch 003: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 048 | Time: 0.0418s | Train MSE: 30.22 | Train MAE: 3.86 | Val MSE: 49.00 | Val MAE: 5.84
# Epoch 049 | Time: 0.0351s | Train MSE: 28.84 | Train MAE: 3.77 | Val MSE: 12.76 | Val MAE: 2.72
# Epoch 050 | Time: 0.0484s | Train MSE: 16.27 | Train MAE: 2.96 | Val MSE: 22.92 | Val MAE: 3.78
# Sweep Finished. Test MSE: 29.31890240837546
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_mse</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_mae</td><td>▁</td></tr><tr><td>test_mse</td><td>▁</td></tr><tr><td>time_per_epoch</td><td>▃▁▅▂▃▃▃▅▁▃▅▂▃▃▃█▄▆▄█▅▇▁▄▂▁▅▁▃▄▁▄▄▂▂▁▄▃▃▄</td></tr><tr><td>train_mae</td><td>█▃▃▃▂▂▂▃▂▂▂▂▂▂▁▁▁▂▁▂▁▁▂▁▂▁▂▁▂▁▁▁▁▁▂▁▂▂▂▁</td></tr><tr><td>train_mse</td><td>█▂▂▂▂▁▁▂▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁</td></tr><tr><td>val_mae</td><td>█▃▂▂▄▁▂▄▂▂▁▁▂▃▂▁▂▂▁▂▁▂▂▁▃▂▂▁▁▁▂▁▃▁▁▁▂▃▄▂</td></tr><tr><td>val_mse</td><td>█▂▁▁▃▁▁▂▂▁▁▁▂▁▁▁▁▁▁▁▁▂▁▁▂▁▁▁▁▁▁▂▁▁▁▁▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_mse</td><td>8.49288</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>lr</td><td>0.00493</td></tr><tr><td>test_mae</td><td>3.89075</td></tr><tr><td>test_mse</td><td>29.3189</td></tr><tr><td>time_per_epoch</td><td>0.04838</td></tr><tr><td>train_mae</td><td>2.96479</td></tr><tr><td>train_mse</td><td>16.27464</td></tr><tr><td>val_mae</td><td>3.77759</td></tr><tr><td>val_mse</td><td>22.92204</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glowing-sweep-2</strong> at: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/qyaefqcc' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/qyaefqcc</a><br> View project at: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20260818_141451-qyaefqcc/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 0hcyk80v with config:
# wandb: 	architecture: MLP
# wandb: 	batch_size: 16
# wandb: 	epochs: 50
# wandb: 	learning_rate: 0.0025895020292814597
# wandb: 	optimizer: sgd
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# Tracking run with wandb version 0.28.0
# Run data is saved locally in <code>/content/wandb/run-20260818_141506-0hcyk80v</code>
# Syncing run <strong><a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/0hcyk80v' target="_blank">sage-sweep-3</a></strong> to <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw</a>
#  View project at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch</a>
#  View sweep at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw</a>
#  View run at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/0hcyk80v' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/0hcyk80v</a>
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Seeds set to 42 for reproducibility.
# ---- Epoch 001: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 001 | Time: 0.0734s | Train MSE: 192.21 | Train MAE: 10.56 | Val MSE: 31.92 | Val MAE: 4.59
# ---- Epoch 002: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 002 | Time: 0.0922s | Train MSE: 65.81 | Train MAE: 5.58 | Val MSE: 19.19 | Val MAE: 3.42
# Epoch 003 | Time: 0.0793s | Train MSE: 28.70 | Train MAE: 3.80 | Val MSE: 44.73 | Val MAE: 5.11
# ---- Epoch 004: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 004 | Time: 0.0818s | Train MSE: 40.26 | Train MAE: 4.59 | Val MSE: 16.80 | Val MAE: 3.37
# ---- Epoch 005: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 005 | Time: 0.0853s | Train MSE: 37.40 | Train MAE: 4.33 | Val MSE: 16.35 | Val MAE: 3.22
# Epoch 006 | Time: 0.0773s | Train MSE: 30.63 | Train MAE: 4.01 | Val MSE: 28.36 | Val MAE: 3.61
# Epoch 007 | Time: 0.0819s | Train MSE: 38.63 | Train MAE: 4.50 | Val MSE: 22.79 | Val MAE: 3.98
# Epoch 008 | Time: 0.0712s | Train MSE: 35.56 | Train MAE: 4.31 | Val MSE: 18.83 | Val MAE: 3.40
# ---- Epoch 009: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 009 | Time: 0.0799s | Train MSE: 34.43 | Train MAE: 4.40 | Val MSE: 14.06 | Val MAE: 2.67
# Epoch 010 | Time: 0.0776s | Train MSE: 27.87 | Train MAE: 3.84 | Val MSE: 39.94 | Val MAE: 4.96
# Epoch 011 | Time: 0.0740s | Train MSE: 36.41 | Train MAE: 4.32 | Val MSE: 29.18 | Val MAE: 3.74
# Epoch 012 | Time: 0.0812s | Train MSE: 41.42 | Train MAE: 4.72 | Val MSE: 43.07 | Val MAE: 5.18
# Epoch 013 | Time: 0.0738s | Train MSE: 35.17 | Train MAE: 4.20 | Val MSE: 22.28 | Val MAE: 3.55
# Epoch 014 | Time: 0.0775s | Train MSE: 27.47 | Train MAE: 3.60 | Val MSE: 32.63 | Val MAE: 4.40
td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_mse</td><td>9.74554</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>lr</td><td>0.00259</td></tr><tr><td>test_mae</td><td>3.56993</td></tr><tr><td>test_mse</td><td>28.38298</td></tr><tr><td>time_per_epoch</td><td>0.0765</td></tr><tr><td>train_mae</td><td>3.46608</td></tr><tr><td>train_mse</td><td>23.49641</td></tr><tr><td>val_mae</td><td>3.03807</td></tr><tr><td>val_mse</td><td>16.93726</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sage-sweep-3</strong> at: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/0hcyk80v' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/0hcyk80v</a><br> View project at: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20260818_141506-0hcyk80v/logs</code>
# wandb: Agent Starting Run: 9uaydq5a with config:
# wandb: 	architecture: MLP
# wandb: 	batch_size: 16
# wandb: 	epochs: 50
# wandb: 	learning_rate: 0.00769215011486595
# wandb: 	optimizer: sgd
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# Tracking run with wandb version 0.28.0
# Run data is saved locally in <code>/content/wandb/run-20260818_141517-9uaydq5a</code>
# Syncing run <strong><a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/9uaydq5a' target="_blank">effortless-sweep-4</a></strong> to <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw</a>
#  View project at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch</a>
#  View sweep at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw</a>
#  View run at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/9uaydq5a' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/9uaydq5a</a>
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Seeds set to 42 for reproducibility.
# ---- Epoch 001: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 001 | Time: 0.0831s | Train MSE: 168.01 | Train MAE: 9.45 | Val MSE: 73.83 | Val MAE: 7.23
# ---- Epoch 002: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 002 | Time: 0.0810s | Train MSE: 75.96 | Train MAE: 5.89 | Val MSE: 41.76 | Val MAE: 4.74
# Epoch 003 | Time: 0.0753s | Train MSE: 36.49 | Train MAE: 4.24 | Val MSE: 42.91 | Val MAE: 4.79
# Epoch 004 | Time: 0.0771s | Train MSE: 47.76 | Train MAE: 4.79 | Val MSE: 76.82 | Val MAE: 6.59
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_mse</td><td>█▄▄▄▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>lr</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_mae</td><td>▁</td></tr><tr><td>test_mse</td><td>▁</td></tr><tr><td>time_per_epoch</td><td>▅▄▃▃▃▅▁▅▄▂▂█▅▁▄▄▂▄▃▄▁▇▁▃▄▃▄▄▃▃▁▇▇▁▅▆▂▃▂▅</td></tr><tr><td>train_mae</td><td>█▄▂▂▂▂▂▁▁▂▁▁▁▂▃▂▁▂▂▂▂▂▂▂▁▁▁▂▂▂▃▃▃▂▂▂▃▃▃▃</td></tr><tr><td>train_mse</td><td>█▃▁▂▁▂▂▁▁▁▂▁▁▂▂▂▁▂▁▂▁▂▁▂▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>val_mae</td><td>█▄▄▇▃▂▂▁▅▂▃▄▂▃▂▄▃▃▅▁▂▅▄▄▅▂▂▆▄▅▅▄▃▃▄▆▃▄▄▄</td></tr><tr><td>val_mse</td><td>█▄▄█▂▁▂▁▇▂▃▄▁▃▂▅▃▃▅▁▅▂▆▄▃▂▂█▄▅▆▆▄▄▄▆▄▄▅▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_mse</td><td>14.0258</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>lr</td><td>0.00769</td></tr><tr><td>test_mae</td><td>4.44728</td></tr><tr><td>test_mse</td><td>29.43936</td></tr><tr><td>time_per_epoch</td><td>0.08321</td></tr><tr><td>train_mae</td><td>4.94249</td></tr><tr><td>train_mse</td><td>47.23536</td></tr><tr><td>val_mae</td><td>4.66689</td></tr><tr><td>val_mse</td><td>44.85899</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">effortless-sweep-4</strong> at: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/9uaydq5a' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/9uaydq5a</a><br> View project at: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20260818_141517-9uaydq5a/logs</code>
# wandb: Agent Starting Run: rz0qi6l8 with config:
# wandb: 	architecture: MLP
# wandb: 	batch_size: 16
# wandb: 	epochs: 50
# wandb: 	learning_rate: 0.008595834770973521
# wandb: 	optimizer: sgd
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# Tracking run with wandb version 0.28.0
# Run data is saved locally in <code>/content/wandb/run-20260818_141528-rz0qi6l8</code>
# Syncing run <strong><a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/rz0qi6l8' target="_blank">serene-sweep-5</a></strong> to <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw</a>
#  View project at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch</a>
#  View sweep at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/sweeps/pxt0f7qw</a>
#  View run at <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/rz0qi6l8' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/rz0qi6l8</a>
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Seeds set to 42 for reproducibility.
# ---- Epoch 001: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 001 | Time: 0.0724s | Train MSE: 161.62 | Train MAE: 9.38 | Val MSE: 98.24 | Val MAE: 7.69
# ---- Epoch 002: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 002 | Time: 0.0814s | Train MSE: 57.64 | Train MAE: 5.24 | Val MSE: 15.82 | Val MAE: 2.97
# Epoch 003 | Time: 0.0892s | Train MSE: 39.11 | Train MAE: 4.49 | Val MSE: 43.43 | Val MAE: 4.97
# Epoch 004 | Time: 0.0796s | Train MSE: 44.75 | Train MAE: 4.63 | Val MSE: 50.57 | Val MAE: 5.19
# Epoch 005 | Time: 0.0780s | Train MSE: 35.35 | Train MAE: 4.05 | Val MSE: 19.94 | Val MAE: 3.37
# Epoch 006 | Time: 0.0745s | Train MSE: 33.66 | Train MAE: 3.93 | Val MSE: 30.20 | Val MAE: 4.24
# Epoch 007 | Time: 0.0804s | Train MSE: 31.22 | Train MAE: 3.88 | Val MSE: 21.16 | Val MAE: 3.45
# Epoch 008 | Time: 0.0696s | Train MSE: 36.58 | Train MAE: 4.16 | Val MSE: 17.57 | Val MAE: 3.04
# Epoch 009 | Time: 0.0789s | Train MSE: 34.21 | Train MAE: 4.13 | Val MSE: 32.79 | Val MAE: 4.25
# Epoch 010 | Time: 0.0781s | Train MSE: 28.59 | Train MAE: 3.66 | Val MSE: 62.84 | Val MAE: 5.28
# Epoch 011 | Time: 0.0762s | Train MSE: 40.72 | Train MAE: 4.31 | Val MSE: 36.03 | Val MAE: 4.48
# Epoch 012 | Time: 0.0787s | Train MSE: 57.39 | Train MAE: 5.60 | Val MSE: 21.80 | Val MAE: 3.56
# Epoch 013 | Time: 0.0716s | Train MSE: 41.67 | Train MAE: 4.43 | Val MSE: 31.93 | Val MAE: 4.27
# Epoch 014 | Time: 0.0775s | Train MSE: 38.17 | Train MAE: 4.43 | Val MSE: 54.34 | Val MAE: 5.04
# ---- Epoch 015: Full checkpoint saved to 'best_checkpoint.tar'
# Epoch 015 | Time: 0.0814s | Train MSE: 35.52 | Train MAE: 4.10 | Val MSE: 13.42 | Val MAE: 2.93
# Epoch 016 | Time: 0.0773s | Train MSE: 30.22 | Train MAE: 3.88 | Val MSE: 44.77 | Val MAE: 4.67
td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">serene-sweep-5</strong> at: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/rz0qi6l8' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch/runs/rz0qi6l8</a><br> View project at: <a href='https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch' target="_blank">https://wandb.ai/gsas_nida/DLclass_MLP2_PyTorch</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20260818_141528-rz0qi6l8/logs</code>

# %% [markdown]
# # 5. Evaluate the model (test set)

# %%
# Recreate the 'test_loader' here because the one inside 'train_sweep()' was local and had a variable batch_size.
# For inference, any batch_size works (it only affects speed).
print("Re-creating test_loader for final inference...")
final_test_loader = torch.utils.data.DataLoader(test_ds, batch_size=32)
# Out:
# Re-creating test_loader for final inference...

# %%
# Evaluate the last model
last_mse, last_mae = evaluate(model, final_test_loader, torch.nn.MSELoss(), torch.nn.L1Loss())

# %%
# Load and evaluate the best model (saved to WandB during training)
best_model = auto_load_from_sweep(sweep_id, model_filename=best_model_path)
best_model = best_model.to(device)
best_mse, best_mae = evaluate(best_model, final_test_loader, torch.nn.MSELoss(), torch.nn.L1Loss())
# Out:
# wandb: Sorting runs by +summary_metrics.best_val_mse
# Analyzing sweep: gsas_nida/DLclass_MLP2_PyTorch/pxt0f7qw
# Best Run Found: glowing-sweep-2 (ID: qyaefqcc)
# Best best_val_mse: 8.49288215824202
# Downloading 'best_checkpoint.tar'...
# Model loaded successfully!

# %%
print("\n" + "="*45)
print("SIDE-BY-SIDE EVALUATION ON TEST SET")
print(f"Device: {device}")
print("="*45)
print(f"{'Metric':<15} | {'Best Model':>12} | {'Last Model':>12}")
print(f"{'-'*15}-+-{'-'*12}-+-{'-'*12}")
print(f"{'MSE (Loss)':<15} | {best_mse:>12.4f} | {last_mse:>12.4f}")
print(f"{'MAE (Eval)':<15} | {best_mae:>12.4f} | {last_mae:>12.4f}")
print("="*45)
# Out:
# =============================================
# SIDE-BY-SIDE EVALUATION ON TEST SET
# Device: cpu
# =============================================
# Metric          |   Best Model |   Last Model
# ----------------+--------------+-------------
# MSE (Loss)      |      26.4966 |     514.7672
# MAE (Eval)      |       3.0125 |      21.3900
# =============================================

# %% [markdown]
# # 6. Inference

# %%
# Inference Examples using the Best Model
print("\n--- Inference Examples (Best Model) ---")
X_test_batch, Y_test_batch = next(iter(final_test_loader))

# Single Sample
single_sample = X_test_batch[0].unsqueeze(0).to(device)
single_pred = best_model(single_sample)
print(f"\nSingle Sample Pred: {single_pred.item():.2f} | Actual: {Y_test_batch[0].item():.2f}")

# Batch (subset)
batch_samples = X_test_batch[:5].to(device)
batch_preds = best_model(batch_samples)
print(f"\nBatch Preds (first 5):\n{batch_preds.squeeze().tolist()}")
print(f"Actual Labels (first 5):\n{Y_test_batch[:5].squeeze().tolist()}")
# Out:
# --- Inference Examples (Best Model) ---
#
# Single Sample Pred: 22.20 | Actual: 21.20
#
# Batch Preds (first 5):
# [22.203596115112305, 22.97818374633789, 14.74315357208252, 19.54448127746582, 14.972275733947754]
# Actual Labels (first 5):
# [21.200000762939453, 23.200000762939453, 27.5, 19.799999237060547, 14.100000381469727]
